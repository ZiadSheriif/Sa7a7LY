# %%
# import from skimage
from skimage.color import rgb2gray
from skimage.filters import sobel, sobel_h, sobel_v, prewitt, roberts, gaussian
from skimage.feature import canny
import skimage.io as io

# import from matplotlib
import matplotlib.pyplot as plt

# import from numpy
import numpy as np

# import open cv
import cv2 as cv

# import utils
from utils.commonfunctions import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 14
#      11 import numpy as np
#      13 # import open cv
# ---> 14 import cv2 as cv
#      16 # import utils
#      17 from utils.commonfunctions import *
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# Read image
colored_img = io.imread("datasets/dataset_module1/00.jpg")

# convert image to gray scale
grey_scale = rgb2gray(colored_img)

# filter image
filtered_img = gaussian(image = grey_scale, sigma=1)

# Show images
show_images(images=[filtered_img])
